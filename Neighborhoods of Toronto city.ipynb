# %% [markdown]
# # Segmenting and Clustering Neighborhoods in the city of Toronto

# %% [markdown]
# ## PART-1

# %% [markdown]
# ### Importing packages

# %%
import pandas as pd
import numpy as np

import geopy

# %%
import pandas as pd

# %% [markdown]
# ### Loading the required table from Wikipedia

# %%
link = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

wiki_table = pd.read_html(link)
wiki_table = wiki_table[0]
wiki_table.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
wiki_table.shape
# Out:
# (180, 3)

# %%
wiki_table = wiki_table.rename(columns={'Postal code':'PostalCode'})

# %% [markdown]
# ### Filtering out the rows that have 'Not Assigned' values

# %%
dataset = wiki_table[wiki_table['Borough']!='Not assigned'].reset_index(drop=True)
dataset.head(10)
# Out:
#   PostalCode           Borough                                  Neighborhood
# 0        M3A        North York                                     Parkwoods
# 1        M4A        North York                              Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 3        M6A        North York             Lawrence Manor / Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government
# 5        M9A         Etobicoke                              Islington Avenue
# 6        M1B       Scarborough                               Malvern / Rouge
# 7        M3B        North York                                     Don Mills
# 8        M4B         East York              Parkview Hill / Woodbine Gardens
# 9        M5B  Downtown Toronto                      Garden District, Ryerson

# %%
len(dataset[dataset['Neighborhood']=='NaN'])
# Out:
# 0

# %%
dataset.shape
# Out:
# (103, 3)

# %%
dataset.dtypes
# Out:
# PostalCode      object
# Borough         object
# Neighborhood    object
# dtype: object

# %%
len(dataset['Borough'].unique())
# Out:
# 10

# %% [markdown]
# ### Preparing the data with the required postal codes

# %%
filtered_postal_codes = ['M5G','M2H','M4B','M1J','M4G','M4M','M1R','M9V','M9L','M5V','M1B','M5A']

# %%
data = pd.DataFrame(columns = ['PostalCode','Borough','Neighborhood'])
for i in filtered_postal_codes:
    table = dataset[dataset['PostalCode']==i]
    data = data.append(table)

# %%
data.reset_index(drop=True)
# Out:
#    PostalCode           Borough  \
# 0         M5G  Downtown Toronto
# 1         M2H        North York
# 2         M4B         East York
# 3         M1J       Scarborough
# 4         M4G         East York
# 5         M4M      East Toronto
# 6         M1R       Scarborough
# 7         M9V         Etobicoke
# 8         M9L        North York
# 9         M5V  Downtown Toronto
# 10        M1B       Scarborough
# 11        M5A  Downtown Toronto
#
#                                          Neighborhood
# 0                                  Central Bay Street
# 1                                   Hillcrest Village
# 2                    Parkview Hill / Woodbine Gardens
# 3                                 Scarborough Village
# 4                                             Leaside
# 5                                     Studio District
# 6                                  Wexford / Maryvale
# 7   South Steeles / Silverstone / Humbergate / Jam...
# ...

# %%
data.shape
# Out:
# (12, 3)

# %% [markdown]
# ## PART-2

# %%
# !wget -q -O 'Geospatial_Coordinates.csv' http://cocl.us/Geospatial_data
print('Loaded successfully!')
# Out:
# Loaded successfully!

# %%
dataset = pd.read_csv('Geospatial_Coordinates.csv')
dataset
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...
